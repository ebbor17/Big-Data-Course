# %%
import pandas as pd
df_swing = pd. read_csv('2008_swing_states.csv')
df_swing[['state', 'county','total_votes','dem_votes', 'dem_share']]
# Out:
#     state           county  total_votes  dem_votes  dem_share
# 0      PA      Erie County       127691      75775      60.08
# 1      PA  Bradford County        25787      10306      40.64
# 2      PA     Tioga County        17984       6390      36.07
# 3      PA    McKean County        15947       6465      41.21
# 4      PA    Potter County         7507       2300      31.04
# ..    ...              ...          ...        ...        ...
# 217    OH  Hamilton County       425086     225213      53.53
# 218    OH  Highland County        19186       6856      36.54
# 219    OH   Hocking County        12961       6259      49.58
# 220    OH   Licking County        82356      33932      41.97
# 221    OH   Madison County        17454       6532      38.11
#
# [222 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
_= plt.hist(df_swing['dem_share'])
_= plt.xlabel('percent of votes for Obama')
_= plt.ylabel('Number of Counties')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
_= sns.swarmplot(x='state', y='dem_share', data=df_swing)
_= plt.xlabel('state')
_= plt.ylabel('percent of vates for Obama')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import numpy as np
x = np.sort(df_swing['dem_share'])
y = np.arange(1, len(x)+1) / len(x)
_= plt.plot(x, y, marker='.', linestyle='none')
_= plt.xlabel('Percent of votes for Obama')
_= plt.ylabel('Empirical Cumulative Distribution Function')
_= plt.margins(0.01)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import pandas as pd
df_swing = pd. read_csv('2008_swing_states.csv')
df_swing[['state', 'county','total_votes','dem_votes', 'dem_share']]
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Polygon

df_swing.columns
# Out:
# Index(['state', 'county', 'total_votes', 'dem_votes', 'rep_votes',
#        'dem_share'],
#       dtype='object')

# %%
plt.boxplot(df_swing.dem_share)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19894735c48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19894508988>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1989499e888>],
#  'medians': [<matplotlib.lines.Line2D at 0x198946c1188>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19894973088>],
#  'means': []}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df_swing = pd. read_csv('2008_swing_states.csv')
df_swing[['state', 'county','total_votes','dem_votes', 'dem_share']]
from sklearn.linear_model import LinearRegression
x = df_swing['dem_votes'].values.reshape(-1,1)
y =  df_swing['total_votes'].values.reshape(-1,1)
lr = LinearRegression()
lr.fit(x,y)
Y_pred = lr.predict(x)

plt.scatter(x,y)
plt.plot(x,Y_pred, color='red')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
